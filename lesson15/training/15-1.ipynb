# %%
from tensorflow.keras import Input
Input(shape=(13,), name="Input")
# Out:
# 2025-11-29 02:57:52.933905: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <KerasTensor shape=(None, 13), dtype=float32, sparse=False, ragged=False, name=Input>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


# Определение Sequential модели с 3 слоями
model = keras.Sequential(
    [
        layers.Dense(2, activation="relu", name="layer1"),
        layers.Dense(3, activation="relu", name="layer2"),
        layers.Dense(4, name="layer3"),
    ]
)
# Вызываем модель на тестовых входных данных
x = tf.ones((3, 3))
y = model(x)
# Out:
# 2025-11-29 02:59:03.687631: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764374347.116900   13247 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9709 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:03:00.0, compute capability: 8.6

# %%
model.layers
# Out:
# [<Dense name=layer1, built=True>,
#  <Dense name=layer2, built=True>,
#  <Dense name=layer3, built=True>]

# %%
model2 = keras.Sequential()
# Последовательный конструктор принимает name аргументы, так же как и любой слой или модели в Keras.
model2.add(layers.Dense(2, activation="relu", name="layer1"))
model2.add(layers.Dense(3, activation="relu", name="layer2"))
model2.add(layers.Dense(4, name="layer3"))

# Вызываем модель на тестовых входных данных
y2 = model2(x)

# %%
model2.pop()
model2.layers
# Out:
# [<Dense name=layer1, built=True>, <Dense name=layer2, built=True>]

# %%
layer = layers.Dense(3)
layer.weights
# Out:
# []

# %%
x = tf.ones((1, 4))
y = layer(x)
layer.weights
# Out:
# [<Variable path=dense/kernel, shape=(4, 3), dtype=float32, value=[[ 0.5510963   0.83866227  0.55937445]
#   [ 0.15328014 -0.30513537  0.22089982]
#   [ 0.25949645  0.600891   -0.58941066]
#   [ 0.43809104 -0.00509405  0.04125518]]>,
#  <Variable path=dense/bias, shape=(3,), dtype=float32, value=[0. 0. 0.]>]

# %%
model34 = keras.Sequential(
    [
        layers.Dense(2, activation="relu"),
        layers.Dense(3, activation="relu"),
        layers.Dense(4),
    ]
)
print(model34.weights)
# Out:
# []

# %%
model = keras.Sequential(
    [
        layers.Dense(2, activation="relu"),
        layers.Dense(3, activation="relu"),
        layers.Dense(4),
    ]
)

x = tf.ones((1, 4))
y = model(x)
print("Число весов после вызова модели:", len(model.weights))  # 6
# Out:
# Число весов после вызова модели: 6

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (1, 2)                 │            10 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (1, 3)                 │             9 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (1, 4)                 │            16 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 35 (140.00 B)
#  Trainable params: 35 (140.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model = keras.Sequential()
model.add(keras.Input(shape=(4,)))
model.add(layers.Dense(2, activation="relu"))

model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 2)              │            10 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10 (40.00 B)
#  Trainable params: 10 (40.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense

# %%
inputs = Input(shape=(13,), name="Input")
input = Dense(10, activation="relu")(inputs)

# %%
hidden = Dense(10, activation="relu")(input)
output = Dense(1)(hidden)

# %%
model = Model(inputs, output)

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)              │ (None, 13)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │           140 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 261 (1.02 KB)
#  Trainable params: 261 (1.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='mse', optimizer='rmsprop')

# %%
from keras.datasets import boston_housing
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()

# %%
mean = train_data.mean(axis=0) # Находим среднее значение по столбцам (по признакам)
train_data -= mean # вычитаем среднее значение для каждого признака
std = train_data.std(axis=0) # вычисляем стандартное отклонение
train_data /= std # для каждого признака полученная разность делится на стандартное отклонение

# повторяем процедуру для тестовых данных
test_data -= mean
test_data /= std

# %%
from keras import models
from keras import layers
def build_model():
    model = models.Sequential()
    model.add(layers.Dense(64, activation='relu', input_shape=(train_data.shape[1],)))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(1))
    model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    return model

# %%
model = build_model()
# Out:
# /home/user/.venvs/gptlab/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from keras import utils
utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True, show_layer_activations=True)

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /home/user/.venvs/gptlab/lib/python3.12/site-packages (0.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
history = model.fit(train_data, train_targets, validation_data=(test_data, test_targets),
 epochs=100, batch_size=10, verbose=1)
# Out:
# Epoch 1/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7973 - mae: 1.1796 - val_loss: 19.0418 - val_mae: 2.8371
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8675 - mae: 1.1934 - val_loss: 17.1115 - val_mae: 2.6834
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7574 - mae: 1.1498 - val_loss: 16.4786 - val_mae: 2.6262
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7759 - mae: 1.1685 - val_loss: 16.5664 - val_mae: 2.5712
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7661 - mae: 1.1664 - val_loss: 18.5897 - val_mae: 2.8186
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7520 - mae: 1.1514 - val_loss: 17.0567 - val_mae: 2.5606
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7998 - mae: 1.1504 - val_loss: 18.0403 - val_mae: 2.7779
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6139 - mae: 1.1289 - val_loss: 16.8947 - val_mae: 2.6641
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6732 - mae: 1.1637 - val_loss: 17.0481 - val_mae: 2.6225
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7140 - mae: 1.1243 - val_loss: 17.6437 - val_mae: 2.7484
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7063 - mae: 1.1662 - val_loss: 16.0208 - val_mae: 2.5328
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6454 - mae: 1.1234 - val_loss: 17.8025 - val_mae: 2.7080
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5582 - mae: 1.1050 - val_loss: 17.7224 - val_mae: 2.7459
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6460 - mae: 1.1155 - val_loss: 17.3654 - val_mae: 2.6522
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6548 - mae: 1.1131 - val_loss: 18.0829 - val_mae: 2.6928
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7294 - mae: 1.1363 - val_loss: 17.0158 - val_mae: 2.5713
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6048 - mae: 1.1071 - val_loss: 17.0969 - val_mae: 2.5962
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5913 - mae: 1.1170 - val_loss: 16.8920 - val_mae: 2.6161
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6721 - mae: 1.1379 - val_loss: 17.1303 - val_mae: 2.5996
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6379 - mae: 1.1094 - val_loss: 16.6052 - val_mae: 2.5669
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5383 - mae: 1.1052 - val_loss: 17.8573 - val_mae: 2.6556
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5188 - mae: 1.1090 - val_loss: 17.5199 - val_mae: 2.6355
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5767 - mae: 1.0994 - val_loss: 17.2434 - val_mae: 2.6042
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5571 - mae: 1.1206 - val_loss: 16.4936 - val_mae: 2.6014
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5313 - mae: 1.1052 - val_loss: 18.6901 - val_mae: 2.7893
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5781 - mae: 1.1250 - val_loss: 16.6787 - val_mae: 2.6315
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5834 - mae: 1.1331 - val_loss: 16.2368 - val_mae: 2.5358
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5124 - mae: 1.0848 - val_loss: 17.6716 - val_mae: 2.6423
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5858 - mae: 1.1243 - val_loss: 17.2094 - val_mae: 2.6265
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4275 - mae: 1.1049 - val_loss: 16.8409 - val_mae: 2.5574
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5871 - mae: 1.1022 - val_loss: 17.1257 - val_mae: 2.6300
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4349 - mae: 1.0880 - val_loss: 17.8603 - val_mae: 2.7235
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4653 - mae: 1.0791 - val_loss: 16.2451 - val_mae: 2.5296
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3553 - mae: 1.0620 - val_loss: 17.5522 - val_mae: 2.6046
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4434 - mae: 1.0959 - val_loss: 16.3586 - val_mae: 2.5128
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4477 - mae: 1.0941 - val_loss: 16.1197 - val_mae: 2.4872
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4076 - mae: 1.0601 - val_loss: 18.4790 - val_mae: 2.7145
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3471 - mae: 1.0521 - val_loss: 18.1833 - val_mae: 2.7313
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4543 - mae: 1.0765 - val_loss: 18.5648 - val_mae: 2.7646
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4887 - mae: 1.1092 - val_loss: 17.3947 - val_mae: 2.5861
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3765 - mae: 1.0681 - val_loss: 16.7975 - val_mae: 2.5262
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4597 - mae: 1.0832 - val_loss: 17.1567 - val_mae: 2.5628
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2967 - mae: 1.0343 - val_loss: 17.2768 - val_mae: 2.6064
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4012 - mae: 1.0703 - val_loss: 17.9385 - val_mae: 2.6849
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3607 - mae: 1.0765 - val_loss: 16.5436 - val_mae: 2.4826
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2968 - mae: 1.0466 - val_loss: 18.4829 - val_mae: 2.7748
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3053 - mae: 1.0586 - val_loss: 17.4231 - val_mae: 2.6223
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3150 - mae: 1.0494 - val_loss: 17.8386 - val_mae: 2.5981
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2893 - mae: 1.0384 - val_loss: 17.1730 - val_mae: 2.5795
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3047 - mae: 1.0540 - val_loss: 17.0127 - val_mae: 2.4941
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2233 - mae: 1.0715 - val_loss: 16.6488 - val_mae: 2.5622
# Epoch 52/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2585 - mae: 1.0136 - val_loss: 19.1160 - val_mae: 2.7166
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3424 - mae: 1.0346 - val_loss: 17.0027 - val_mae: 2.5061
# Epoch 54/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2449 - mae: 1.0367 - val_loss: 17.0539 - val_mae: 2.5012
# Epoch 55/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2939 - mae: 1.0432 - val_loss: 18.3219 - val_mae: 2.7373
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1765 - mae: 1.0411 - val_loss: 18.0550 - val_mae: 2.7232
# Epoch 57/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2709 - mae: 1.0481 - val_loss: 17.2191 - val_mae: 2.5661
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3147 - mae: 1.0303 - val_loss: 17.9137 - val_mae: 2.6628
# Epoch 59/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1819 - mae: 1.0302 - val_loss: 16.8457 - val_mae: 2.5276
# Epoch 60/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2035 - mae: 1.0188 - val_loss: 17.0148 - val_mae: 2.5965
# Epoch 61/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2501 - mae: 1.0456 - val_loss: 16.3221 - val_mae: 2.4759
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1253 - mae: 1.0417 - val_loss: 17.4120 - val_mae: 2.6059
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2927 - mae: 1.0496 - val_loss: 16.8543 - val_mae: 2.5669
# Epoch 64/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2579 - mae: 1.0375 - val_loss: 16.7609 - val_mae: 2.5299
# Epoch 65/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1814 - mae: 1.0269 - val_loss: 17.6247 - val_mae: 2.6023
# Epoch 66/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1822 - mae: 1.0343 - val_loss: 16.9179 - val_mae: 2.5181
# Epoch 67/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1742 - mae: 1.0374 - val_loss: 17.8163 - val_mae: 2.6044
# Epoch 68/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1453 - mae: 1.0024 - val_loss: 21.1386 - val_mae: 3.0097
# Epoch 69/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1462 - mae: 1.0501 - val_loss: 17.1380 - val_mae: 2.5861
# Epoch 70/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0937 - mae: 1.0075 - val_loss: 17.8601 - val_mae: 2.6023
# Epoch 71/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1495 - mae: 1.0098 - val_loss: 18.2176 - val_mae: 2.6931
# Epoch 72/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1950 - mae: 1.0283 - val_loss: 17.5533 - val_mae: 2.5663
# Epoch 73/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1117 - mae: 1.0020 - val_loss: 16.9944 - val_mae: 2.5244
# Epoch 74/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0287 - mae: 0.9877 - val_loss: 18.3867 - val_mae: 2.6952
# Epoch 75/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0520 - mae: 1.0028 - val_loss: 17.3579 - val_mae: 2.5877
# Epoch 76/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0273 - mae: 1.0002 - val_loss: 17.1000 - val_mae: 2.5136
# Epoch 77/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0163 - mae: 0.9769 - val_loss: 17.3092 - val_mae: 2.5117
# Epoch 78/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0237 - mae: 0.9972 - val_loss: 18.6575 - val_mae: 2.6941
# Epoch 79/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0243 - mae: 0.9854 - val_loss: 17.1725 - val_mae: 2.5641
# Epoch 80/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9485 - mae: 0.9790 - val_loss: 19.0465 - val_mae: 2.7281
# Epoch 81/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0574 - mae: 1.0279 - val_loss: 17.1218 - val_mae: 2.5361
# Epoch 82/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1516 - mae: 1.0120 - val_loss: 17.7996 - val_mae: 2.6342
# Epoch 83/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9401 - mae: 0.9866 - val_loss: 17.7754 - val_mae: 2.6380
# Epoch 84/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0635 - mae: 0.9922 - val_loss: 18.0972 - val_mae: 2.5617
# Epoch 85/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9179 - mae: 0.9943 - val_loss: 18.0292 - val_mae: 2.6584
# Epoch 86/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1520 - mae: 1.0207 - val_loss: 18.2672 - val_mae: 2.6255
# Epoch 87/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0515 - mae: 0.9708 - val_loss: 18.6332 - val_mae: 2.6966
# Epoch 88/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9865 - mae: 0.9726 - val_loss: 17.2814 - val_mae: 2.5540
# Epoch 89/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0394 - mae: 0.9526 - val_loss: 18.3690 - val_mae: 2.6027
# Epoch 90/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0860 - mae: 1.0262 - val_loss: 17.9899 - val_mae: 2.6533
# Epoch 91/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8928 - mae: 0.9535 - val_loss: 17.2199 - val_mae: 2.4988
# Epoch 92/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0371 - mae: 0.9903 - val_loss: 17.8792 - val_mae: 2.6163
# Epoch 93/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9193 - mae: 0.9686 - val_loss: 19.1773 - val_mae: 2.7815
# Epoch 94/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8794 - mae: 0.9721 - val_loss: 22.2242 - val_mae: 3.1562
# Epoch 95/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1141 - mae: 1.0266 - val_loss: 17.4066 - val_mae: 2.5375
# Epoch 96/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9583 - mae: 0.9743 - val_loss: 18.9132 - val_mae: 2.7404
# Epoch 97/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8979 - mae: 0.9486 - val_loss: 19.1594 - val_mae: 2.6861
# Epoch 98/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0472 - mae: 0.9812 - val_loss: 17.9699 - val_mae: 2.5480
# Epoch 99/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9482 - mae: 0.9648 - val_loss: 18.1310 - val_mae: 2.6301
# Epoch 100/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9766 - mae: 0.9864 - val_loss: 18.7861 - val_mae: 2.6665

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(history.history['mae'], label='Средняя абсолютная ошибка на обучающем наборе')
plt.plot(history.history['val_mae'], label='Средняя абсолютная ошибка на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Средняя абсолютная ошибка')
plt.legend()
plt.show()

# %%
# Сохранение весов модели в файл
model.save_weights('boston.weights.h5')

# Загрузка весов модели из файла
#model.load_weights('boston.weights.h5')
